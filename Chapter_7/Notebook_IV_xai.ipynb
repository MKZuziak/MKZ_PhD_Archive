# %%
import os
import operator
import math

import matplotlib
import networkx

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import wilcoxon
from scipy.stats import friedmanchisquare

# %%
matplotlib.rcParams['font.family'] = 'sans-serif'
matplotlib.rcParams['font.sans-serif'] = 'Arial'
matplotlib.use('agg')

# %%
# Author: Hassan Ismail Fawaz <hassan.ismail-fawaz@uha.fr>
#         Germain Forestier <germain.forestier@uha.fr>
#         Jonathan Weber <jonathan.weber@uha.fr>
#         Lhassane Idoumghar <lhassane.idoumghar@uha.fr>
#         Pierre-Alain Muller <pierre-alain.muller@uha.fr>
# License: GPL3

# inspired from orange3 https://docs.orange.biolab.si/3/data-mining-library/reference/evaluation.cd.html
def graph_ranks(avranks, names, p_values, cd=None, cdmethod=None, lowv=None, highv=None,
                width=6, textspace=1, reverse=False, filename=None, labels=False, **kwargs):
    """
    Draws a CD graph, which is used to display  the differences in methods'
    performance. See Janez Demsar, Statistical Comparisons of Classifiers over
    Multiple Data Sets, 7(Jan):1--30, 2006.

    Needs matplotlib to work.

    The image is ploted on `plt` imported using
    `import matplotlib.pyplot as plt`.

    Args:
        avranks (list of float): average ranks of methods.
        names (list of str): names of methods.
        cd (float): Critical difference used for statistically significance of
            difference between methods.
        cdmethod (int, optional): the method that is compared with other methods
            If omitted, show pairwise comparison of methods
        lowv (int, optional): the lowest shown rank
        highv (int, optional): the highest shown rank
        width (int, optional): default width in inches (default: 6)
        textspace (int, optional): space on figure sides (in inches) for the
            method names (default: 1)
        reverse (bool, optional):  if set to `True`, the lowest rank is on the
            right (default: `False`)
        filename (str, optional): output file name (with extension). If not
            given, the function does not write a file.
        labels (bool, optional): if set to `True`, the calculated avg rank
        values will be displayed
    """
    try:
        import matplotlib
        import matplotlib.pyplot as plt
        from matplotlib.backends.backend_agg import FigureCanvasAgg
    except ImportError:
        raise ImportError("Function graph_ranks requires matplotlib.")

    width = float(width)
    textspace = float(textspace)

    def nth(l, n):
        """
        Returns only nth elemnt in a list.
        """
        n = lloc(l, n)
        return [a[n] for a in l]

    def lloc(l, n):
        """
        List location in list of list structure.
        Enable the use of negative locations:
        -1 is the last element, -2 second last...
        """
        if n < 0:
            return len(l[0]) + n
        else:
            return n

    def mxrange(lr):
        """
        Multiple xranges. Can be used to traverse matrices.
        This function is very slow due to unknown number of
        parameters.

        >>> mxrange([3,5])
        [(0, 0), (0, 1), (0, 2), (1, 0), (1, 1), (1, 2)]

        >>> mxrange([[3,5,1],[9,0,-3]])
        [(3, 9), (3, 6), (3, 3), (4, 9), (4, 6), (4, 3)]

        """
        if not len(lr):
            yield ()
        else:
            # it can work with single numbers
            index = lr[0]
            if isinstance(index, int):
                index = [index]
            for a in range(*index):
                for b in mxrange(lr[1:]):
                    yield tuple([a] + list(b))

    def print_figure(fig, *args, **kwargs):
        canvas = FigureCanvasAgg(fig)
        canvas.print_figure(*args, **kwargs)

    sums = avranks

    nnames = names
    ssums = sums

    if lowv is None:
        lowv = min(1, int(math.floor(min(ssums))))
    if highv is None:
        highv = max(len(avranks), int(math.ceil(max(ssums))))

    cline = 0.4

    k = len(sums)

    lines = None

    linesblank = 0
    scalewidth = width - 2 * textspace

    def rankpos(rank):
        if not reverse:
            a = rank - lowv
        else:
            a = highv - rank
        return textspace + scalewidth / (highv - lowv) * a

    distanceh = 0.25

    cline += distanceh

    # calculate height needed height of an image
    minnotsignificant = max(2 * 0.2, linesblank)
    height = cline + ((k + 1) / 2) * 0.2 + minnotsignificant

    fig = plt.figure(figsize=(width, height))
    fig.set_facecolor('white')
    ax = fig.add_axes([0, 0, 1, 1])  # reverse y axis
    ax.set_axis_off()

    hf = 1. / height  # height factor
    wf = 1. / width

    def hfl(l):
        return [a * hf for a in l]

    def wfl(l):
        return [a * wf for a in l]

    # Upper left corner is (0,0).
    ax.plot([0, 1], [0, 1], c="w")
    ax.set_xlim(0, 1)
    ax.set_ylim(1, 0)

    def line(l, color='k', **kwargs):
        """
        Input is a list of pairs of points.
        """
        ax.plot(wfl(nth(l, 0)), hfl(nth(l, 1)), color=color, **kwargs)

    def text(x, y, s, *args, **kwargs):
        ax.text(wf * x, hf * y, s, *args, **kwargs)

    line([(textspace, cline), (width - textspace, cline)], linewidth=2)

    bigtick = 0.3
    smalltick = 0.15
    linewidth = 2.0
    linewidth_sign = 4.0

    tick = None
    for a in list(np.arange(lowv, highv, 0.5)) + [highv]:
        tick = smalltick
        if a == int(a):
            tick = bigtick
        line([(rankpos(a), cline - tick / 2),
              (rankpos(a), cline)],
             linewidth=2)

    for a in range(lowv, highv + 1):
        text(rankpos(a), cline - tick / 2 - 0.05, str(a),
             ha="center", va="bottom", size=16)

    k = len(ssums)

    def filter_names(name):
        return name

    space_between_names = 0.24

    for i in range(math.ceil(k / 2)):
        chei = cline + minnotsignificant + i * space_between_names
        line([(rankpos(ssums[i]), cline),
              (rankpos(ssums[i]), chei),
              (textspace - 0.1, chei)],
             linewidth=linewidth)
        if labels:
            text(textspace + 0.3, chei - 0.075, format(ssums[i], '.4f'), ha="right", va="center", size=10)
        text(textspace - 0.2, chei, filter_names(nnames[i]), ha="right", va="center", size=16)

    for i in range(math.ceil(k / 2), k):
        chei = cline + minnotsignificant + (k - i - 1) * space_between_names
        line([(rankpos(ssums[i]), cline),
              (rankpos(ssums[i]), chei),
              (textspace + scalewidth + 0.1, chei)],
             linewidth=linewidth)
        if labels:
            text(textspace + scalewidth - 0.3, chei - 0.075, format(ssums[i], '.4f'), ha="left", va="center", size=10)
        text(textspace + scalewidth + 0.2, chei, filter_names(nnames[i]),
             ha="left", va="center", size=16)

    # no-significance lines
    def draw_lines(lines, side=0.05, height=0.1):
        start = cline + 0.2

        for l, r in lines:
            line([(rankpos(ssums[l]) - side, start),
                  (rankpos(ssums[r]) + side, start)],
                 linewidth=linewidth_sign)
            start += height
            print('drawing: ', l, r)

    # draw_lines(lines)
    start = cline + 0.2
    side = -0.02
    height = 0.1

    # draw no significant lines
    # get the cliques
    cliques = form_cliques(p_values, nnames)
    i = 1
    achieved_half = False
    print(nnames)
    for clq in cliques:
        if len(clq) == 1:
            continue
        print(clq)
        min_idx = np.array(clq).min()
        max_idx = np.array(clq).max()
        if min_idx >= len(nnames) / 2 and achieved_half == False:
            start = cline + 0.25
            achieved_half = True
        line([(rankpos(ssums[min_idx]) - side, start),
              (rankpos(ssums[max_idx]) + side, start)],
             linewidth=linewidth_sign)
        start += height


def form_cliques(p_values, nnames):
    """
    This method forms the cliques
    """
    # first form the numpy matrix data
    m = len(nnames)
    g_data = np.zeros((m, m), dtype=np.int64)
    for p in p_values:
        if p[3] == False:
            i = np.where(nnames == p[0])[0][0]
            j = np.where(nnames == p[1])[0][0]
            min_i = min(i, j)
            max_j = max(i, j)
            g_data[min_i, max_j] = 1

    g = networkx.Graph(g_data)
    return networkx.find_cliques(g)


def draw_cd_diagram(df_perf=None, alpha=0.05, title=None, labels=False, filename='cd_diagram.png'):
    """
    Draws the critical difference diagram given the list of pairwise classifiers that are
    significant or not
    """
    p_values, average_ranks, _ = wilcoxon_holm(df_perf=df_perf, alpha=alpha)

    print(average_ranks)

    for p in p_values:
        print(p)


    graph_ranks(average_ranks.values, average_ranks.keys(), p_values,
                cd=None, reverse=True, width=9, textspace=1.5, labels=labels)

    font = {'family': 'sans-serif',
        'color':  'black',
        'weight': 'normal',
        'size': 22,
        }
    if title:
        plt.title(title,fontdict=font, y=0.9, x=0.5)
    plt.savefig(filename ,bbox_inches='tight')

def wilcoxon_holm(alpha=0.05, df_perf=None):
    """
    Applies the wilcoxon signed rank test between each pair of algorithm and then use Holm
    to reject the null's hypothesis
    """
    print(pd.unique(df_perf['algorithm']))
    # count the number of tested datasets per classifier
    df_counts = pd.DataFrame({'count': df_perf.groupby(
        ['algorithm']).size()}).reset_index()
    # get the maximum number of tested datasets
    max_nb_datasets = df_counts['count'].max()
    # get the list of classifiers who have been tested on nb_max_datasets
    classifiers = list(df_counts.loc[df_counts['count'] == max_nb_datasets]
                       ['algorithm'])
    # test the null hypothesis using friedman before doing a post-hoc analysis
    friedman_p_value = friedmanchisquare(*(
        np.array(df_perf.loc[df_perf['algorithm'] == c]['score'])
        for c in classifiers))[1]
    if friedman_p_value >= alpha:
        # then the null hypothesis over the entire classifiers cannot be rejected
        print('the null hypothesis over the entire classifiers cannot be rejected')
        exit()
    # get the number of classifiers
    m = len(classifiers)
    # init array that contains the p-values calculated by the Wilcoxon signed rank test
    p_values = []
    # loop through the algorithms to compare pairwise
    for i in range(m - 1):
        # get the name of classifier one
        classifier_1 = classifiers[i]
        # get the performance of classifier one
        perf_1 = np.array(df_perf.loc[df_perf['algorithm'] == classifier_1]['score']
                          , dtype=np.float64)
        for j in range(i + 1, m):
            # get the name of the second classifier
            classifier_2 = classifiers[j]
            # get the performance of classifier one
            perf_2 = np.array(df_perf.loc[df_perf['algorithm'] == classifier_2]
                              ['score'], dtype=np.float64)
            # calculate the p_value
            p_value = wilcoxon(perf_1, perf_2, zero_method='pratt')[1]
            # appen to the list
            p_values.append((classifier_1, classifier_2, p_value, False))
    # get the number of hypothesis
    k = len(p_values)
    # sort the list in acsending manner of p-value
    p_values.sort(key=operator.itemgetter(2))

    # loop through the hypothesis
    for i in range(k):
        # correct alpha with holm
        new_alpha = float(alpha / (k - i))
        # test if significant after holm's correction of alpha
        if p_values[i][2] <= new_alpha:
            p_values[i] = (p_values[i][0], p_values[i][1], p_values[i][2], True)
        else:
            # stop
            break
    # compute the average ranks to be returned (useful for drawing the cd diagram)
    # sort the dataframe of performances
    sorted_df_perf = df_perf.loc[df_perf['algorithm'].isin(classifiers)]. \
        sort_values(['algorithm', 'dataset_name'])
    # get the rank data
    rank_data = np.array(sorted_df_perf['score']).reshape(m, max_nb_datasets)

    # create the data frame containg the accuracies
    df_ranks = pd.DataFrame(data=rank_data, index=np.sort(classifiers), columns=
    np.unique(sorted_df_perf['dataset_name']))

    # number of wins
    dfff = df_ranks.rank(ascending=False)
    print(dfff[dfff == 1.0].sum(axis=1))

    # average the ranks
    average_ranks = df_ranks.rank(ascending=False).mean(axis=1).sort_values(ascending=False)
    # return the p-values and the average ranks
    return p_values, average_ranks, max_nb_datasets

# %%
ALGOS = ['baseline', 'briggs', 'sattler', 'kmeans', 'affinity', 'meanshift', 'HDBSCAN']
DATASETS = ['MNIST', 'FMNIST', 'CIFAR10', 'PATHMNIST']
OVERLAPS = ['overlaping', 'nonoverlaping']
BALANCES = ['balanced', 'imbalanced']
EXPERIMENTS = ['experiment1A', 'experiment1B', 'experiment1C']
TOTAL_ROWS = len(ALGOS) * len(DATASETS) * len(OVERLAPS) * len(BALANCES)
EXPERIMENTS_ROOT = os.path.join(os.getcwd(), 'explanations')

# %% [markdown]
# # Section I: Calculation of a Mean INDE values across clusters

# %% [markdown]
# ## Section I Part A (In-Distribution Experiments)

# %%
root = os.path.join(EXPERIMENTS_ROOT, EXPERIMENTS[0])
avg_results = []
for dataset in DATASETS:
    for overlap in OVERLAPS:
        for balance in BALANCES:
            for algo in ALGOS:
                frame = pd.read_csv(os.path.join(root, dataset, f"{dataset}_{overlap}_{balance}_15_{algo}.csv"))
                frame_info = frame[['ins_mean', 'del_mean']].mean(axis=0)
                avg_results.append(
                    {
                        'algorithm': algo,
                        'dataset_name': f'{dataset} {overlap} {balance}',
                        'insertion': frame_info['ins_mean'],
                        'deletion': frame_info['del_mean']
                    }
                )

expa_frame = pd.DataFrame(avg_results)
expa_frame.to_csv(os.path.join(root, 'INDE_avg.csv'))

# %% [markdown]
# ## Section I Part B (Out-of-Distribution Experiments)

# %%
root = os.path.join(EXPERIMENTS_ROOT, EXPERIMENTS[1])
avg_results = []
for dataset in DATASETS:
    for overlap in OVERLAPS:
        for balance in BALANCES:
            for algo in ALGOS:
                frame = pd.read_csv(os.path.join(root, dataset, f"{dataset}_{overlap}_{balance}_15_{algo}.csv"))
                frame_info = frame[['ins_mean', 'del_mean']].mean(axis=0)
                avg_results.append(
                    {
                        'algorithm': algo,
                        'dataset_name': f'{dataset} {overlap} {balance}',
                        'insertion': frame_info['ins_mean'],
                        'deletion': frame_info['del_mean']
                    }
                )

expb_frame = pd.DataFrame(avg_results)
expb_frame.to_csv(os.path.join(root, 'INDE_avg.csv'))

# %% [markdown]
# ## Section I Part C (Orchestrator Test Set Experiments)

# %%
root = os.path.join(EXPERIMENTS_ROOT, EXPERIMENTS[2])
avg_results = []
for dataset in DATASETS:
    for overlap in OVERLAPS:
        for balance in BALANCES:
            for algo in ALGOS:
                frame = pd.read_csv(os.path.join(root, dataset, f"{dataset}_{overlap}_{balance}_15_{algo}.csv"))
                frame_info = frame[['ins_mean', 'del_mean']].mean(axis=0)
                avg_results.append(
                    {
                        'algorithm': algo,
                        'dataset_name': f'{dataset} {overlap} {balance}',
                        'insertion': frame_info['ins_mean'],
                        'deletion': frame_info['del_mean']
                    }
                )

expb_frame = pd.DataFrame(avg_results)
expb_frame.to_csv(os.path.join(root, 'INDE_avg.csv'))

# %% [markdown]
# # Section II: Critical Difference Plots

# %% [markdown]
# ## Section II Part A (In-Distribution Experiments)

# %% [markdown]
# ### Insertion

# %%
root = os.path.join(EXPERIMENTS_ROOT, EXPERIMENTS[0])
expa_frame = pd.read_csv(os.path.join(root, 'INDE_avg.csv'))
expa_frame.drop(['deletion'], axis=1, inplace=True)
expa_frame.rename(columns={"insertion":"score"}, inplace=True)
draw_cd_diagram(df_perf=expa_frame, title='Insertion', labels=True, filename=os.path.join(root, 'Insertion_CD_plot.png'))
# Out:
# ['baseline' 'briggs' 'sattler' 'kmeans' 'affinity' 'meanshift' 'HDBSCAN']
# HDBSCAN      5.0
# affinity     1.0
# baseline     0.0
# briggs       5.0
# kmeans       2.0
# meanshift    3.0
# sattler      0.0
# dtype: float64
# baseline     6.0625
# sattler      5.7500
# affinity     5.0625
# briggs       3.6250
# meanshift    2.9375
# kmeans       2.5000
# HDBSCAN      2.0625
# dtype: float64
# ('HDBSCAN', 'baseline', 3.0517578125e-05, True)
# ('HDBSCAN', 'sattler', 3.0517578125e-05, True)
# ('baseline', 'kmeans', 3.0517578125e-05, True)
# ('baseline', 'meanshift', 3.0517578125e-05, True)
# ('kmeans', 'sattler', 3.0517578125e-05, True)
# ('HDBSCAN', 'affinity', 0.000152587890625, True)
# ('affinity', 'kmeans', 0.000152587890625, True)
# ('meanshift', 'sattler', 0.000762939453125, True)
# ('affinity', 'meanshift', 0.002685546875, True)
# ('baseline', 'briggs', 0.00335693359375, True)
# ('briggs', 'sattler', 0.00335693359375, True)
# ('HDBSCAN', 'briggs', 0.02899169921875, False)
# ('affinity', 'baseline', 0.02899169921875, False)
# ('affinity', 'sattler', 0.05767822265625, False)
# ('briggs', 'kmeans', 0.065399169921875, False)
# ('HDBSCAN', 'meanshift', 0.07391357421875, False)
# ('affinity', 'briggs', 0.1590576171875, False)
# ('HDBSCAN', 'kmeans', 0.322509765625, False)
# ('baseline', 'sattler', 0.375457763671875, False)
# ('briggs', 'meanshift', 0.375457763671875, False)
# ('kmeans', 'meanshift', 0.668548583984375, False)
# Index(['baseline', 'sattler', 'affinity', 'briggs', 'meanshift', 'kmeans',
#        'HDBSCAN'],
#       dtype='object')
# [0, 1, 2]
# [3, 2]
# [3, 4, 5, 6]

# %% [markdown]
# ### Deletion

# %%
root = os.path.join(EXPERIMENTS_ROOT, EXPERIMENTS[0])
expa_frame = pd.read_csv(os.path.join(root, 'INDE_avg.csv'))
expa_frame.drop(['insertion'], axis=1, inplace=True)
expa_frame.rename(columns={"deletion":"score"}, inplace=True)
draw_cd_diagram(df_perf=expa_frame, title='Deletion', labels=True, filename=os.path.join(root, 'Deletion_CD_plot.png'))
# Out:
# ['baseline' 'briggs' 'sattler' 'kmeans' 'affinity' 'meanshift' 'HDBSCAN']
# HDBSCAN      4.0
# affinity     2.0
# baseline     0.0
# briggs       2.0
# kmeans       3.0
# meanshift    5.0
# sattler      0.0
# dtype: float64
# baseline     6.1250
# sattler      5.2500
# briggs       3.9375
# affinity     3.5625
# meanshift    3.3750
# HDBSCAN      2.8750
# kmeans       2.8750
# dtype: float64
# ('baseline', 'kmeans', 0.000213623046875, True)
# ('baseline', 'meanshift', 0.00030517578125, True)
# ('HDBSCAN', 'baseline', 0.00042724609375, True)
# ('affinity', 'baseline', 0.001312255859375, True)
# ('HDBSCAN', 'sattler', 0.004180908203125, False)
# ('kmeans', 'sattler', 0.00762939453125, False)
# ('affinity', 'sattler', 0.009185791015625, False)
# ('meanshift', 'sattler', 0.021392822265625, False)
# ('HDBSCAN', 'briggs', 0.02496337890625, False)
# ('baseline', 'briggs', 0.02496337890625, False)
# ('baseline', 'sattler', 0.09344482421875, False)
# ('briggs', 'kmeans', 0.14385986328125, False)
# ('briggs', 'sattler', 0.252227783203125, False)
# ('affinity', 'kmeans', 0.274444580078125, False)
# ('HDBSCAN', 'affinity', 0.40374755859375, False)
# ('affinity', 'meanshift', 0.4637451171875, False)
# ('HDBSCAN', 'meanshift', 0.5618896484375, False)
# ('briggs', 'meanshift', 0.596588134765625, False)
# ('affinity', 'briggs', 0.743560791015625, False)
# ('kmeans', 'meanshift', 0.781951904296875, False)
# ('HDBSCAN', 'kmeans', 0.979949951171875, False)
# Index(['baseline', 'sattler', 'briggs', 'affinity', 'meanshift', 'HDBSCAN',
#        'kmeans'],
#       dtype='object')
# [1, 2, 0]
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# ## Section II Part B (Out-of-Distribution Experiments)

# %% [markdown]
# ### Insertion

# %%
root = os.path.join(EXPERIMENTS_ROOT, EXPERIMENTS[1])
expa_frame = pd.read_csv(os.path.join(root, 'INDE_avg.csv'))
expa_frame.drop(['deletion'], axis=1, inplace=True)
expa_frame.rename(columns={"insertion":"score"}, inplace=True)
draw_cd_diagram(df_perf=expa_frame, title='Insertion', labels=True, filename=os.path.join(root, 'Insertion_CD_plot.png'))
# Out:
# ['baseline' 'briggs' 'sattler' 'kmeans' 'affinity' 'meanshift' 'HDBSCAN']
# HDBSCAN      7.0
# affinity     2.0
# baseline     0.0
# briggs       1.0
# kmeans       3.0
# meanshift    3.0
# sattler      0.0
# dtype: float64
# briggs       3.555556
# affinity     3.214286
# meanshift    2.866667
# kmeans       2.250000
# HDBSCAN      2.125000
# baseline          NaN
# sattler           NaN
# dtype: float64
# ('HDBSCAN', 'affinity', nan, False)
# ('HDBSCAN', 'baseline', nan, False)
# ('HDBSCAN', 'briggs', nan, False)
# ('HDBSCAN', 'kmeans', 0.668548583984375, False)
# ('HDBSCAN', 'meanshift', nan, False)
# ('HDBSCAN', 'sattler', nan, False)
# ('affinity', 'baseline', nan, False)
# ('affinity', 'briggs', nan, False)
# ('affinity', 'kmeans', nan, False)
# ('affinity', 'meanshift', nan, False)
# ('affinity', 'sattler', nan, False)
# ('baseline', 'briggs', nan, False)
# ('baseline', 'kmeans', nan, False)
# ('baseline', 'meanshift', nan, False)
# ('baseline', 'sattler', nan, False)
# ('briggs', 'kmeans', nan, False)
# ('briggs', 'meanshift', nan, False)
# ('briggs', 'sattler', nan, False)
# ('kmeans', 'meanshift', nan, False)
# ('kmeans', 'sattler', nan, False)
# ('meanshift', 'sattler', nan, False)
# Index(['briggs', 'affinity', 'meanshift', 'kmeans', 'HDBSCAN', 'baseline',
#        'sattler'],
#       dtype='object')
# [0, 1, 2, 3, 4, 5, 6]

# %% [markdown]
# ### Deletion

# %%
root = os.path.join(EXPERIMENTS_ROOT, EXPERIMENTS[1])
expa_frame = pd.read_csv(os.path.join(root, 'INDE_avg.csv'))
expa_frame.drop(['insertion'], axis=1, inplace=True)
expa_frame.rename(columns={"deletion":"score"}, inplace=True)
draw_cd_diagram(df_perf=expa_frame, title='Deletion', labels=True, filename=os.path.join(root, 'Deletion_CD_plot.png'))
# Out:
# ['baseline' 'briggs' 'sattler' 'kmeans' 'affinity' 'meanshift' 'HDBSCAN']
# HDBSCAN      4.0
# affinity     8.0
# baseline     0.0
# briggs       0.0
# kmeans       2.0
# meanshift    2.0
# sattler      0.0
# dtype: float64
# briggs       3.777778
# meanshift    3.000000
# kmeans       2.812500
# HDBSCAN      2.500000
# affinity     1.857143
# baseline          NaN
# sattler           NaN
# dtype: float64
# ('HDBSCAN', 'affinity', nan, False)
# ('HDBSCAN', 'baseline', nan, False)
# ('HDBSCAN', 'briggs', nan, False)
# ('HDBSCAN', 'kmeans', 0.5618896484375, False)
# ('HDBSCAN', 'meanshift', nan, False)
# ('HDBSCAN', 'sattler', nan, False)
# ('affinity', 'baseline', nan, False)
# ('affinity', 'briggs', nan, False)
# ('affinity', 'kmeans', nan, False)
# ('affinity', 'meanshift', nan, False)
# ('affinity', 'sattler', nan, False)
# ('baseline', 'briggs', nan, False)
# ('baseline', 'kmeans', nan, False)
# ('baseline', 'meanshift', nan, False)
# ('baseline', 'sattler', nan, False)
# ('briggs', 'kmeans', nan, False)
# ('briggs', 'meanshift', nan, False)
# ('briggs', 'sattler', nan, False)
# ('kmeans', 'meanshift', nan, False)
# ('kmeans', 'sattler', nan, False)
# ('meanshift', 'sattler', nan, False)
# Index(['briggs', 'meanshift', 'kmeans', 'HDBSCAN', 'affinity', 'baseline',
#        'sattler'],
#       dtype='object')
# [0, 1, 2, 3, 4, 5, 6]

# %% [markdown]
# ## Section II Part C (Orchestrator Test Set Experiments)

# %% [markdown]
# ### Insertion

# %%
root = os.path.join(EXPERIMENTS_ROOT, EXPERIMENTS[2])
expa_frame = pd.read_csv(os.path.join(root, 'INDE_avg.csv'))
expa_frame.drop(['deletion'], axis=1, inplace=True)
expa_frame.rename(columns={"insertion":"score"}, inplace=True)
draw_cd_diagram(df_perf=expa_frame, title='Insertion', labels=True, filename=os.path.join(root, 'Insertion_CD_plot.png'))
# Out:
# ['baseline' 'briggs' 'sattler' 'kmeans' 'affinity' 'meanshift' 'HDBSCAN']
# HDBSCAN      5.0
# affinity     0.0
# baseline     0.0
# briggs       7.0
# kmeans       2.0
# meanshift    2.0
# sattler      0.0
# dtype: float64
# baseline     5.7500
# sattler      5.0625
# affinity     4.8125
# meanshift    3.4375
# briggs       3.3750
# HDBSCAN      2.8750
# kmeans       2.6875
# dtype: float64
# ('baseline', 'kmeans', 0.000152587890625, True)
# ('HDBSCAN', 'baseline', 0.00030517578125, True)
# ('baseline', 'meanshift', 0.00030517578125, True)
# ('kmeans', 'sattler', 0.000579833984375, True)
# ('HDBSCAN', 'sattler', 0.001007080078125, True)
# ('affinity', 'kmeans', 0.001312255859375, True)
# ('HDBSCAN', 'affinity', 0.00213623046875, True)
# ('baseline', 'briggs', 0.009185791015625, False)
# ('affinity', 'meanshift', 0.021392822265625, False)
# ('briggs', 'sattler', 0.02899169921875, False)
# ('meanshift', 'sattler', 0.02899169921875, False)
# ('affinity', 'briggs', 0.033538818359375, False)
# ('affinity', 'baseline', 0.07391357421875, False)
# ('baseline', 'sattler', 0.116668701171875, False)
# ('briggs', 'kmeans', 0.375457763671875, False)
# ('HDBSCAN', 'briggs', 0.40374755859375, False)
# ('HDBSCAN', 'meanshift', 0.40374755859375, False)
# ('affinity', 'sattler', 0.433197021484375, False)
# ('kmeans', 'meanshift', 0.528167724609375, False)
# ('briggs', 'meanshift', 0.899932861328125, False)
# ('HDBSCAN', 'kmeans', 0.93988037109375, False)
# Index(['baseline', 'sattler', 'affinity', 'meanshift', 'briggs', 'HDBSCAN',
#        'kmeans'],
#       dtype='object')
# [4, 0, 1, 2]
# [4, 3, 1, 2]
# [4, 3, 5, 6]

# %% [markdown]
# ### Deletion

# %%
root = os.path.join(EXPERIMENTS_ROOT, EXPERIMENTS[2])
expa_frame = pd.read_csv(os.path.join(root, 'INDE_avg.csv'))
expa_frame.drop(['insertion'], axis=1, inplace=True)
expa_frame.rename(columns={"deletion":"score"}, inplace=True)
draw_cd_diagram(df_perf=expa_frame, title='Deletion', labels=True, filename=os.path.join(root, 'Deletion_CD_plot.png'))
# Out:
# ['baseline' 'briggs' 'sattler' 'kmeans' 'affinity' 'meanshift' 'HDBSCAN']
# HDBSCAN      3.0
# affinity     0.0
# baseline     1.0
# briggs       6.0
# kmeans       1.0
# meanshift    4.0
# sattler      1.0
# dtype: float64
# baseline     5.6875
# sattler      5.0625
# briggs       4.0000
# affinity     3.8750
# kmeans       3.3750
# meanshift    3.2500
# HDBSCAN      2.7500
# dtype: float64
# ('baseline', 'kmeans', 0.001007080078125, True)
# ('baseline', 'meanshift', 0.001007080078125, True)
# ('HDBSCAN', 'baseline', 0.001312255859375, True)
# ('affinity', 'baseline', 0.002685546875, True)
# ('kmeans', 'sattler', 0.00628662109375, False)
# ('HDBSCAN', 'sattler', 0.00762939453125, False)
# ('baseline', 'briggs', 0.021392822265625, False)
# ('meanshift', 'sattler', 0.033538818359375, False)
# ('affinity', 'sattler', 0.05767822265625, False)
# ('HDBSCAN', 'affinity', 0.09344482421875, False)
# ('affinity', 'kmeans', 0.129730224609375, False)
# ('affinity', 'meanshift', 0.14385986328125, False)
# ('HDBSCAN', 'briggs', 0.1590576171875, False)
# ('briggs', 'kmeans', 0.2978515625, False)
# ('baseline', 'sattler', 0.375457763671875, False)
# ('kmeans', 'meanshift', 0.375457763671875, False)
# ('HDBSCAN', 'kmeans', 0.40374755859375, False)
# ('briggs', 'meanshift', 0.4637451171875, False)
# ('briggs', 'sattler', 0.4637451171875, False)
# ('HDBSCAN', 'meanshift', 0.49542236328125, False)
# ('affinity', 'briggs', 0.860260009765625, False)
# Index(['baseline', 'sattler', 'briggs', 'affinity', 'kmeans', 'meanshift',
#        'HDBSCAN'],
#       dtype='object')
# [1, 2, 0]
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# # Section III: Critical Difference Plots for Individual Datasets

# %% [markdown]
# ## Section III Part A (In-Distribution Experiments)

# %% [markdown]
# ### Insertion

# %%
root = os.path.join(EXPERIMENTS_ROOT, EXPERIMENTS[0])
expa_frame = pd.read_csv(os.path.join(root, 'INDE_avg.csv'))
expa_frame.drop(['deletion'], axis=1, inplace=True)
expa_frame.rename(columns={"insertion":"score"}, inplace=True)

for dataset in DATASETS:
    selected_entries = expa_frame[expa_frame['dataset_name'].str.contains(rf'\b{dataset}\b', regex=True)]
    draw_cd_diagram(df_perf=selected_entries, title='Insertion', labels=True, filename=os.path.join(root, dataset, 'cd_plot', 'Insertion_CD_plot.png'))
# Out:
# ['baseline' 'briggs' 'sattler' 'kmeans' 'affinity' 'meanshift' 'HDBSCAN']
# HDBSCAN      2.0
# affinity     0.0
# baseline     0.0
# briggs       1.0
# kmeans       0.0
# meanshift    1.0
# sattler      0.0
# dtype: float64
# baseline     6.00
# sattler      5.50
# affinity     5.00
# briggs       4.75
# kmeans       2.50
# meanshift    2.25
# HDBSCAN      2.00
# dtype: float64
# ('HDBSCAN', 'affinity', 0.125, False)
# ('HDBSCAN', 'baseline', 0.125, False)
# ('HDBSCAN', 'sattler', 0.125, False)
# ('affinity', 'kmeans', 0.125, False)
# ('affinity', 'meanshift', 0.125, False)
# ('baseline', 'kmeans', 0.125, False)
# ('baseline', 'meanshift', 0.125, False)
# ('kmeans', 'sattler', 0.125, False)
# ('meanshift', 'sattler', 0.125, False)
# ('HDBSCAN', 'briggs', 0.25, False)
# ('affinity', 'baseline', 0.25, False)
# ('briggs', 'kmeans', 0.25, False)
# ('briggs', 'meanshift', 0.25, False)
# ('affinity', 'sattler', 0.375, False)
# ('baseline', 'sattler', 0.375, False)
# ('HDBSCAN', 'meanshift', 0.875, False)
# ('affinity', 'briggs', 0.875, False)
# ('baseline', 'briggs', 0.875, False)
# ('briggs', 'sattler', 0.875, False)
# ('kmeans', 'meanshift', 0.875, False)
# ('HDBSCAN', 'kmeans', 1.0, False)
# Index(['baseline', 'sattler', 'affinity', 'briggs', 'kmeans', 'meanshift',
#        'HDBSCAN'],
#       dtype='object')
# [0, 1, 2, 3, 4, 5, 6]
# ['baseline' 'briggs' 'sattler' 'kmeans' 'affinity' 'meanshift' 'HDBSCAN']
# HDBSCAN      2.0
# affinity     0.0
# baseline     0.0
# briggs       0.0
# kmeans       0.0
# meanshift    2.0
# sattler      0.0
# dtype: float64
# baseline     6.00
# sattler      5.75
# briggs       5.25
# affinity     5.00
# kmeans       2.25
# HDBSCAN      2.00
# meanshift    1.75
# dtype: float64
# ('HDBSCAN', 'affinity', 0.125, False)
# ('HDBSCAN', 'baseline', 0.125, False)
# ('HDBSCAN', 'briggs', 0.125, False)
# ('HDBSCAN', 'sattler', 0.125, False)
# ('affinity', 'kmeans', 0.125, False)
# ('affinity', 'meanshift', 0.125, False)
# ('baseline', 'kmeans', 0.125, False)
# ('baseline', 'meanshift', 0.125, False)
# ('briggs', 'kmeans', 0.125, False)
# ('briggs', 'meanshift', 0.125, False)
# ('kmeans', 'sattler', 0.125, False)
# ('meanshift', 'sattler', 0.125, False)
# ('affinity', 'sattler', 0.25, False)
# ('kmeans', 'meanshift', 0.25, False)
# ('briggs', 'sattler', 0.375, False)
# ('HDBSCAN', 'kmeans', 0.625, False)
# ('affinity', 'baseline', 0.625, False)
# ('baseline', 'briggs', 0.625, False)
# ('baseline', 'sattler', 0.875, False)
# ('HDBSCAN', 'meanshift', 1.0, False)
# ('affinity', 'briggs', 1.0, False)
# Index(['baseline', 'sattler', 'briggs', 'affinity', 'kmeans', 'HDBSCAN',
#        'meanshift'],
#       dtype='object')
# [0, 1, 2, 3, 4, 5, 6]
# ['baseline' 'briggs' 'sattler' 'kmeans' 'affinity' 'meanshift' 'HDBSCAN']
# HDBSCAN      0.0
# affinity     0.0
# baseline     0.0
# briggs       4.0
# kmeans       0.0
# meanshift    0.0
# sattler      0.0
# dtype: float64
# affinity     6.00
# sattler      6.00
# baseline     5.75
# meanshift    3.50
# kmeans       3.25
# HDBSCAN      2.50
# briggs       1.00
# dtype: float64
# ('HDBSCAN', 'affinity', 0.125, False)
# ('HDBSCAN', 'baseline', 0.125, False)
# ('HDBSCAN', 'briggs', 0.125, False)
# ('HDBSCAN', 'sattler', 0.125, False)
# ('affinity', 'briggs', 0.125, False)
# ('affinity', 'kmeans', 0.125, False)
# ('baseline', 'briggs', 0.125, False)
# ('baseline', 'kmeans', 0.125, False)
# ('baseline', 'meanshift', 0.125, False)
# ('briggs', 'kmeans', 0.125, False)
# ('briggs', 'meanshift', 0.125, False)
# ('briggs', 'sattler', 0.125, False)
# ('kmeans', 'sattler', 0.125, False)
# ('meanshift', 'sattler', 0.125, False)
# ('HDBSCAN', 'meanshift', 0.25, False)
# ('affinity', 'meanshift', 0.25, False)
# ('HDBSCAN', 'kmeans', 0.375, False)
# ('baseline', 'sattler', 0.625, False)
# ('affinity', 'baseline', 0.875, False)
# ('affinity', 'sattler', 0.875, False)
# ('kmeans', 'meanshift', 1.0, False)
# Index(['affinity', 'sattler', 'baseline', 'meanshift', 'kmeans', 'HDBSCAN',
#        'briggs'],
#       dtype='object')
# [0, 1, 2, 3, 4, 5, 6]
# ['baseline' 'briggs' 'sattler' 'kmeans' 'affinity' 'meanshift' 'HDBSCAN']
# HDBSCAN      1.0
# affinity     1.0
# baseline     0.0
# briggs       0.0
# kmeans       2.0
# meanshift    0.0
# sattler      0.0
# dtype: float64
# baseline     6.50
# sattler      5.75
# affinity     4.25
# meanshift    4.25
# briggs       3.50
# kmeans       2.00
# HDBSCAN      1.75
# dtype: float64
# ('HDBSCAN', 'baseline', 0.125, False)
# ('HDBSCAN', 'briggs', 0.125, False)
# ('HDBSCAN', 'meanshift', 0.125, False)
# ('HDBSCAN', 'sattler', 0.125, False)
# ('baseline', 'briggs', 0.125, False)
# ('baseline', 'kmeans', 0.125, False)
# ('baseline', 'meanshift', 0.125, False)
# ('briggs', 'kmeans', 0.125, False)
# ('briggs', 'sattler', 0.125, False)
# ('kmeans', 'sattler', 0.125, False)
# ('HDBSCAN', 'affinity', 0.25, False)
# ('affinity', 'baseline', 0.25, False)
# ('affinity', 'kmeans', 0.25, False)
# ('baseline', 'sattler', 0.25, False)
# ('kmeans', 'meanshift', 0.25, False)
# ('affinity', 'briggs', 0.375, False)
# ('briggs', 'meanshift', 0.375, False)
# ('affinity', 'sattler', 0.625, False)
# ('meanshift', 'sattler', 0.625, False)
# ('affinity', 'meanshift', 0.875, False)
# ('HDBSCAN', 'kmeans', 1.0, False)
# Index(['baseline', 'sattler', 'affinity', 'meanshift', 'briggs', 'kmeans',
#        'HDBSCAN'],
#       dtype='object')
# [0, 1, 2, 3, 4, 5, 6]

# %% [markdown]
# ### Deletion

# %%
root = os.path.join(EXPERIMENTS_ROOT, EXPERIMENTS[0])
expa_frame = pd.read_csv(os.path.join(root, 'INDE_avg.csv'))
expa_frame.drop(['insertion'], axis=1, inplace=True)
expa_frame.rename(columns={"deletion":"score"}, inplace=True)

for dataset in DATASETS:
    selected_entries = expa_frame[expa_frame['dataset_name'].str.contains(rf'\b{dataset}\b', regex=True)]
    draw_cd_diagram(df_perf=selected_entries, title='Deletion', labels=True, filename=os.path.join(root, dataset, 'cd_plot', 'Deletion_CD_plot.png'))
# Out:
# ['baseline' 'briggs' 'sattler' 'kmeans' 'affinity' 'meanshift' 'HDBSCAN']
# the null hypothesis over the entire classifiers cannot be rejected
# HDBSCAN      0.0
# affinity     0.0
# baseline     0.0
# briggs       1.0
# kmeans       1.0
# meanshift    2.0
# sattler      0.0
# dtype: float64
# baseline     5.25
# briggs       5.00
# sattler      4.75
# HDBSCAN      3.75
# affinity     3.25
# kmeans       3.25
# meanshift    2.75
# dtype: float64
# ('affinity', 'baseline', 0.25, False)
# ('affinity', 'sattler', 0.25, False)
# ('HDBSCAN', 'kmeans', 0.375, False)
# ('HDBSCAN', 'meanshift', 0.375, False)
# ('HDBSCAN', 'sattler', 0.375, False)
# ('affinity', 'briggs', 0.375, False)
# ('baseline', 'kmeans', 0.375, False)
# ('baseline', 'meanshift', 0.375, False)
# ('briggs', 'kmeans', 0.375, False)
# ('briggs', 'meanshift', 0.375, False)
# ('kmeans', 'meanshift', 0.375, False)
# ('kmeans', 'sattler', 0.375, False)
# ('meanshift', 'sattler', 0.375, False)
# ('HDBSCAN', 'affinity', 0.625, False)
# ('HDBSCAN', 'baseline', 0.625, False)
# ('HDBSCAN', 'briggs', 0.625, False)
# ('affinity', 'kmeans', 0.625, False)
# ('affinity', 'meanshift', 0.625, False)
# ('baseline', 'briggs', 0.625, False)
# ('baseline', 'sattler', 0.875, False)
# ('briggs', 'sattler', 0.875, False)
# Index(['baseline', 'briggs', 'sattler', 'HDBSCAN', 'affinity', 'kmeans',
#        'meanshift'],
#       dtype='object')
# [0, 1, 2, 3, 4, 5, 6]
# ['baseline' 'briggs' 'sattler' 'kmeans' 'affinity' 'meanshift' 'HDBSCAN']
# HDBSCAN      0.0
# affinity     1.0
# baseline     0.0
# briggs       0.0
# kmeans       1.0
# meanshift    2.0
# sattler      0.0
# dtype: float64
# baseline     6.50
# briggs       6.25
# sattler      4.25
# HDBSCAN      3.50
# kmeans       3.00
# meanshift    2.50
# affinity     2.00
# dtype: float64
# ('HDBSCAN', 'affinity', 0.125, False)
# ('HDBSCAN', 'baseline', 0.125, False)
# ('HDBSCAN', 'briggs', 0.125, False)
# ('affinity', 'baseline', 0.125, False)
# ('affinity', 'briggs', 0.125, False)
# ('affinity', 'sattler', 0.125, False)
# ('baseline', 'kmeans', 0.125, False)
# ('baseline', 'meanshift', 0.125, False)
# ('baseline', 'sattler', 0.125, False)
# ('briggs', 'meanshift', 0.125, False)
# ('briggs', 'sattler', 0.125, False)
# ('briggs', 'kmeans', 0.25, False)
# ('meanshift', 'sattler', 0.375, False)
# ('HDBSCAN', 'kmeans', 0.625, False)
# ('HDBSCAN', 'meanshift', 0.625, False)
# ('HDBSCAN', 'sattler', 0.625, False)
# ('kmeans', 'sattler', 0.625, False)
# ('affinity', 'meanshift', 0.875, False)
# ('kmeans', 'meanshift', 0.875, False)
# ('affinity', 'kmeans', 1.0, False)
# ('baseline', 'briggs', 1.0, False)
# Index(['baseline', 'briggs', 'sattler', 'HDBSCAN', 'kmeans', 'meanshift',
#        'affinity'],
#       dtype='object')
# [0, 1, 2, 3, 4, 5, 6]
# ['baseline' 'briggs' 'sattler' 'kmeans' 'affinity' 'meanshift' 'HDBSCAN']
# HDBSCAN      2.0
# affinity     0.0
# baseline     0.0
# briggs       1.0
# kmeans       0.0
# meanshift    1.0
# sattler      0.0
# dtype: float64
# baseline     6.25
# sattler      6.25
# affinity     4.75
# kmeans       3.50
# meanshift    3.50
# HDBSCAN      2.00
# briggs       1.75
# dtype: float64
# ('HDBSCAN', 'affinity', 0.125, False)
# ('HDBSCAN', 'baseline', 0.125, False)
# ('HDBSCAN', 'sattler', 0.125, False)
# ('affinity', 'briggs', 0.125, False)
# ('baseline', 'briggs', 0.125, False)
# ('baseline', 'kmeans', 0.125, False)
# ('baseline', 'meanshift', 0.125, False)
# ('briggs', 'kmeans', 0.125, False)
# ('briggs', 'sattler', 0.125, False)
# ('kmeans', 'sattler', 0.125, False)
# ('meanshift', 'sattler', 0.125, False)
# ('HDBSCAN', 'kmeans', 0.25, False)
# ('HDBSCAN', 'meanshift', 0.25, False)
# ('affinity', 'kmeans', 0.25, False)
# ('affinity', 'sattler', 0.25, False)
# ('briggs', 'meanshift', 0.25, False)
# ('affinity', 'baseline', 0.375, False)
# ('affinity', 'meanshift', 0.625, False)
# ('baseline', 'sattler', 0.875, False)
# ('HDBSCAN', 'briggs', 1.0, False)
# ('kmeans', 'meanshift', 1.0, False)
# Index(['baseline', 'sattler', 'affinity', 'kmeans', 'meanshift', 'HDBSCAN',
#        'briggs'],
#       dtype='object')
# [0, 1, 2, 3, 4, 5, 6]
# ['baseline' 'briggs' 'sattler' 'kmeans' 'affinity' 'meanshift' 'HDBSCAN']
# HDBSCAN      2.0
# affinity     1.0
# baseline     0.0
# briggs       0.0
# kmeans       1.0
# meanshift    0.0
# sattler      0.0
# dtype: float64
# baseline     6.50
# sattler      5.75
# meanshift    4.75
# affinity     4.25
# briggs       2.75
# HDBSCAN      2.25
# kmeans       1.75
# dtype: float64
# ('HDBSCAN', 'baseline', 0.125, False)
# ('HDBSCAN', 'meanshift', 0.125, False)
# ('HDBSCAN', 'sattler', 0.125, False)
# ('baseline', 'briggs', 0.125, False)
# ('baseline', 'kmeans', 0.125, False)
# ('baseline', 'meanshift', 0.125, False)
# ('briggs', 'kmeans', 0.125, False)
# ('briggs', 'meanshift', 0.125, False)
# ('briggs', 'sattler', 0.125, False)
# ('kmeans', 'meanshift', 0.125, False)
# ('kmeans', 'sattler', 0.125, False)
# ('affinity', 'baseline', 0.25, False)
# ('HDBSCAN', 'affinity', 0.375, False)
# ('affinity', 'briggs', 0.375, False)
# ('affinity', 'kmeans', 0.375, False)
# ('baseline', 'sattler', 0.375, False)
# ('HDBSCAN', 'briggs', 0.625, False)
# ('affinity', 'sattler', 0.625, False)
# ('meanshift', 'sattler', 0.625, False)
# ('HDBSCAN', 'kmeans', 0.875, False)
# ('affinity', 'meanshift', 0.875, False)
# Index(['baseline', 'sattler', 'meanshift', 'affinity', 'briggs', 'HDBSCAN',
#        'kmeans'],
#       dtype='object')
# [0, 1, 2, 3, 4, 5, 6]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Section III Part B (Out-of-Distribution Experiments)

# %% [markdown]
# ### Insertion

# %%
root = os.path.join(EXPERIMENTS_ROOT, EXPERIMENTS[1])
expa_frame = pd.read_csv(os.path.join(root, 'INDE_avg.csv'))
expa_frame.drop(['deletion'], axis=1, inplace=True)
expa_frame.rename(columns={"insertion":"score"}, inplace=True)

for dataset in DATASETS:
    selected_entries = expa_frame[expa_frame['dataset_name'].str.contains(rf'\b{dataset}\b', regex=True)]
    draw_cd_diagram(df_perf=selected_entries, title='Insertion', labels=True, filename=os.path.join(root, dataset, 'cd_plot', 'Insertion_CD_plot.png'))
# Out:
# ['baseline' 'briggs' 'sattler' 'kmeans' 'affinity' 'meanshift' 'HDBSCAN']
# HDBSCAN      1.0
# affinity     1.0
# baseline     0.0
# briggs       0.0
# kmeans       0.0
# meanshift    2.0
# sattler      0.0
# dtype: float64
# HDBSCAN      2.75
# affinity     2.50
# kmeans       2.50
# meanshift    2.25
# baseline      NaN
# briggs        NaN
# sattler       NaN
# dtype: float64
# ('HDBSCAN', 'affinity', 0.875, False)
# ('HDBSCAN', 'baseline', nan, False)
# ('HDBSCAN', 'briggs', nan, False)
# ('HDBSCAN', 'meanshift', 0.625, False)
# ('HDBSCAN', 'kmeans', 0.875, False)
# ('HDBSCAN', 'sattler', nan, False)
# ('affinity', 'baseline', nan, False)
# ('affinity', 'briggs', nan, False)
# ('affinity', 'kmeans', 0.875, False)
# ('affinity', 'meanshift', 0.875, False)
# ('affinity', 'sattler', nan, False)
# ('baseline', 'briggs', nan, False)
# ('baseline', 'kmeans', nan, False)
# ('baseline', 'meanshift', nan, False)
# ('baseline', 'sattler', nan, False)
# ('briggs', 'kmeans', nan, False)
# ('briggs', 'meanshift', nan, False)
# ('briggs', 'sattler', nan, False)
# ('kmeans', 'meanshift', 0.875, False)
# ('kmeans', 'sattler', nan, False)
# ('meanshift', 'sattler', nan, False)
# Index(['HDBSCAN', 'affinity', 'kmeans', 'meanshift', 'baseline', 'briggs',
#        'sattler'],
#       dtype='object')
# [0, 1, 2, 3, 4, 5, 6]
# ['baseline' 'briggs' 'sattler' 'kmeans' 'affinity' 'meanshift' 'HDBSCAN']
# HDBSCAN      2.0
# affinity     0.0
# baseline     0.0
# briggs       1.0
# kmeans       0.0
# meanshift    1.0
# sattler      0.0
# dtype: float64
# affinity     4.25
# kmeans       2.75
# HDBSCAN      2.25
# meanshift    1.75
# briggs       1.00
# baseline      NaN
# sattler       NaN
# dtype: float64
# ('HDBSCAN', 'affinity', 0.125, False)
# ('HDBSCAN', 'baseline', nan, False)
# ('HDBSCAN', 'briggs', nan, False)
# ('HDBSCAN', 'kmeans', 0.625, False)
# ('HDBSCAN', 'meanshift', 0.625, False)
# ('HDBSCAN', 'sattler', nan, False)
# ('affinity', 'baseline', nan, False)
# ('affinity', 'briggs', nan, False)
# ('affinity', 'kmeans', 0.125, False)
# ('affinity', 'meanshift', 0.125, False)
# ('affinity', 'sattler', nan, False)
# ('baseline', 'briggs', nan, False)
# ('baseline', 'kmeans', nan, False)
# ('baseline', 'meanshift', nan, False)
# ('baseline', 'sattler', nan, False)
# ('briggs', 'kmeans', nan, False)
# ('briggs', 'meanshift', nan, False)
# ('briggs', 'sattler', nan, False)
# ('kmeans', 'meanshift', 0.125, False)
# ('kmeans', 'sattler', nan, False)
# ('meanshift', 'sattler', nan, False)
# Index(['affinity', 'kmeans', 'HDBSCAN', 'meanshift', 'briggs', 'baseline',
#        'sattler'],
#       dtype='object')
# [0, 1, 2, 3, 4, 5, 6]
# ['baseline' 'briggs' 'sattler' 'kmeans' 'affinity' 'meanshift' 'HDBSCAN']
# HDBSCAN      3.0
# affinity     0.0
# baseline     0.0
# briggs       0.0
# kmeans       1.0
# meanshift    0.0
# sattler      0.0
# dtype: float64
# briggs       3.750000
# affinity     3.500000
# meanshift    3.333333
# kmeans       1.750000
# HDBSCAN      1.500000
# baseline          NaN
# sattler           NaN
# dtype: float64
# ('HDBSCAN', 'affinity', nan, False)
# ('HDBSCAN', 'baseline', nan, False)
# ('HDBSCAN', 'briggs', 0.125, False)
# ('HDBSCAN', 'kmeans', 0.875, False)
# ('HDBSCAN', 'meanshift', nan, False)
# ('HDBSCAN', 'sattler', nan, False)
# ('affinity', 'baseline', nan, False)
# ('affinity', 'briggs', nan, False)
# ('affinity', 'kmeans', nan, False)
# ('affinity', 'meanshift', nan, False)
# ('affinity', 'sattler', nan, False)
# ('baseline', 'briggs', nan, False)
# ('baseline', 'kmeans', nan, False)
# ('baseline', 'meanshift', nan, False)
# ('baseline', 'sattler', nan, False)
# ('briggs', 'kmeans', 0.125, False)
# ('briggs', 'meanshift', nan, False)
# ('briggs', 'sattler', nan, False)
# ('kmeans', 'meanshift', nan, False)
# ('kmeans', 'sattler', nan, False)
# ('meanshift', 'sattler', nan, False)
# Index(['briggs', 'affinity', 'meanshift', 'kmeans', 'HDBSCAN', 'baseline',
#        'sattler'],
#       dtype='object')
# [0, 1, 2, 3, 4, 5, 6]
# ['baseline' 'briggs' 'sattler' 'kmeans' 'affinity' 'meanshift' 'HDBSCAN']
# HDBSCAN      1.0
# affinity     1.0
# baseline     0.0
# briggs       0.0
# kmeans       2.0
# meanshift    0.0
# sattler      0.0
# dtype: float64
# meanshift    4.25
# briggs       4.00
# affinity     2.75
# HDBSCAN      2.00
# kmeans       2.00
# baseline      NaN
# sattler       NaN
# dtype: float64
# ('HDBSCAN', 'affinity', 0.875, False)
# ('HDBSCAN', 'baseline', nan, False)
# ('HDBSCAN', 'briggs', 0.125, False)
# ('kmeans', 'meanshift', 0.125, False)
# ('HDBSCAN', 'meanshift', 0.25, False)
# ('affinity', 'meanshift', 0.375, False)
# ('HDBSCAN', 'kmeans', 0.625, False)
# ('HDBSCAN', 'sattler', nan, False)
# ('affinity', 'baseline', nan, False)
# ('affinity', 'briggs', 0.375, False)
# ('affinity', 'kmeans', 0.875, False)
# ('affinity', 'sattler', nan, False)
# ('baseline', 'briggs', nan, False)
# ('baseline', 'kmeans', nan, False)
# ('baseline', 'meanshift', nan, False)
# ('baseline', 'sattler', nan, False)
# ('briggs', 'kmeans', 0.125, False)
# ('briggs', 'meanshift', 0.375, False)
# ('briggs', 'sattler', nan, False)
# ('kmeans', 'sattler', nan, False)
# ('meanshift', 'sattler', nan, False)
# Index(['meanshift', 'briggs', 'affinity', 'HDBSCAN', 'kmeans', 'baseline',
#        'sattler'],
#       dtype='object')
# [0, 1, 2, 3, 4, 5, 6]

# %% [markdown]
# ### Deletion

# %%
root = os.path.join(EXPERIMENTS_ROOT, EXPERIMENTS[1])
expa_frame = pd.read_csv(os.path.join(root, 'INDE_avg.csv'))
expa_frame.drop(['insertion'], axis=1, inplace=True)
expa_frame.rename(columns={"deletion":"score"}, inplace=True)

for dataset in DATASETS:
    selected_entries = expa_frame[expa_frame['dataset_name'].str.contains(rf'\b{dataset}\b', regex=True)]
    draw_cd_diagram(df_perf=selected_entries, title='Deletion', labels=True, filename=os.path.join(root, dataset, 'cd_plot', 'Deletion_CD_plot.png'))
# Out:
# ['baseline' 'briggs' 'sattler' 'kmeans' 'affinity' 'meanshift' 'HDBSCAN']
# HDBSCAN      0.0
# affinity     3.0
# baseline     0.0
# briggs       0.0
# kmeans       0.0
# meanshift    1.0
# sattler      0.0
# dtype: float64
# kmeans       3.25
# HDBSCAN      3.00
# meanshift    2.25
# affinity     1.50
# baseline      NaN
# briggs        NaN
# sattler       NaN
# dtype: float64
# ('HDBSCAN', 'affinity', 0.25, False)
# ('HDBSCAN', 'baseline', nan, False)
# ('HDBSCAN', 'briggs', nan, False)
# ('affinity', 'kmeans', 0.125, False)
# ('kmeans', 'meanshift', 0.25, False)
# ('HDBSCAN', 'meanshift', 0.375, False)
# ('HDBSCAN', 'kmeans', 0.625, False)
# ('HDBSCAN', 'sattler', nan, False)
# ('affinity', 'baseline', nan, False)
# ('affinity', 'briggs', nan, False)
# ('affinity', 'meanshift', 0.375, False)
# ('affinity', 'sattler', nan, False)
# ('baseline', 'briggs', nan, False)
# ('baseline', 'kmeans', nan, False)
# ('baseline', 'meanshift', nan, False)
# ('baseline', 'sattler', nan, False)
# ('briggs', 'kmeans', nan, False)
# ('briggs', 'meanshift', nan, False)
# ('briggs', 'sattler', nan, False)
# ('kmeans', 'sattler', nan, False)
# ('meanshift', 'sattler', nan, False)
# Index(['kmeans', 'HDBSCAN', 'meanshift', 'affinity', 'baseline', 'briggs',
#        'sattler'],
#       dtype='object')
# [0, 1, 2, 3, 4, 5, 6]
# ['baseline' 'briggs' 'sattler' 'kmeans' 'affinity' 'meanshift' 'HDBSCAN']
# HDBSCAN      0.0
# affinity     4.0
# baseline     0.0
# briggs       0.0
# kmeans       0.0
# meanshift    0.0
# sattler      0.0
# dtype: float64
# kmeans       3.50
# HDBSCAN      3.25
# briggs       3.00
# meanshift    2.75
# affinity     1.00
# baseline      NaN
# sattler       NaN
# dtype: float64
# ('HDBSCAN', 'affinity', 0.125, False)
# ('HDBSCAN', 'baseline', nan, False)
# ('HDBSCAN', 'briggs', nan, False)
# ('affinity', 'kmeans', 0.125, False)
# ('affinity', 'meanshift', 0.125, False)
# ('HDBSCAN', 'meanshift', 0.625, False)
# ('HDBSCAN', 'kmeans', 1.0, False)
# ('HDBSCAN', 'sattler', nan, False)
# ('affinity', 'baseline', nan, False)
# ('affinity', 'briggs', nan, False)
# ('affinity', 'sattler', nan, False)
# ('baseline', 'briggs', nan, False)
# ('baseline', 'kmeans', nan, False)
# ('baseline', 'meanshift', nan, False)
# ('baseline', 'sattler', nan, False)
# ('briggs', 'kmeans', nan, False)
# ('briggs', 'meanshift', nan, False)
# ('briggs', 'sattler', nan, False)
# ('kmeans', 'meanshift', 0.25, False)
# ('kmeans', 'sattler', nan, False)
# ('meanshift', 'sattler', nan, False)
# Index(['kmeans', 'HDBSCAN', 'briggs', 'meanshift', 'affinity', 'baseline',
#        'sattler'],
#       dtype='object')
# [0, 1, 2, 3, 4, 5, 6]
# ['baseline' 'briggs' 'sattler' 'kmeans' 'affinity' 'meanshift' 'HDBSCAN']
# HDBSCAN      3.0
# affinity     0.0
# baseline     0.0
# briggs       0.0
# kmeans       0.0
# meanshift    1.0
# sattler      0.0
# dtype: float64
# briggs       4.000000
# affinity     3.000000
# meanshift    2.666667
# kmeans       2.250000
# HDBSCAN      1.500000
# baseline          NaN
# sattler           NaN
# dtype: float64
# ('HDBSCAN', 'affinity', nan, False)
# ('HDBSCAN', 'baseline', nan, False)
# ('HDBSCAN', 'briggs', 0.125, False)
# ('HDBSCAN', 'kmeans', 0.625, False)
# ('HDBSCAN', 'meanshift', nan, False)
# ('HDBSCAN', 'sattler', nan, False)
# ('affinity', 'baseline', nan, False)
# ('affinity', 'briggs', nan, False)
# ('affinity', 'kmeans', nan, False)
# ('affinity', 'meanshift', nan, False)
# ('affinity', 'sattler', nan, False)
# ('baseline', 'briggs', nan, False)
# ('baseline', 'kmeans', nan, False)
# ('baseline', 'meanshift', nan, False)
# ('baseline', 'sattler', nan, False)
# ('briggs', 'kmeans', 0.125, False)
# ('briggs', 'meanshift', nan, False)
# ('briggs', 'sattler', nan, False)
# ('kmeans', 'meanshift', nan, False)
# ('kmeans', 'sattler', nan, False)
# ('meanshift', 'sattler', nan, False)
# Index(['briggs', 'affinity', 'meanshift', 'kmeans', 'HDBSCAN', 'baseline',
#        'sattler'],
#       dtype='object')
# [0, 1, 2, 3, 4, 5, 6]
# ['baseline' 'briggs' 'sattler' 'kmeans' 'affinity' 'meanshift' 'HDBSCAN']
# HDBSCAN      1.0
# affinity     1.0
# baseline     0.0
# briggs       0.0
# kmeans       2.0
# meanshift    0.0
# sattler      0.0
# dtype: float64
# meanshift    4.25
# briggs       3.75
# affinity     2.50
# HDBSCAN      2.25
# kmeans       2.25
# baseline      NaN
# sattler       NaN
# dtype: float64
# ('HDBSCAN', 'affinity', 1.0, False)
# ('HDBSCAN', 'baseline', nan, False)
# ('HDBSCAN', 'briggs', 0.125, False)
# ('kmeans', 'meanshift', 0.125, False)
# ('HDBSCAN', 'meanshift', 0.25, False)
# ('affinity', 'meanshift', 0.25, False)
# ('HDBSCAN', 'kmeans', 0.625, False)
# ('HDBSCAN', 'sattler', nan, False)
# ('affinity', 'baseline', nan, False)
# ('briggs', 'meanshift', 0.25, False)
# ('affinity', 'briggs', 0.375, False)
# ('affinity', 'kmeans', 1.0, False)
# ('affinity', 'sattler', nan, False)
# ('baseline', 'briggs', nan, False)
# ('baseline', 'kmeans', nan, False)
# ('baseline', 'meanshift', nan, False)
# ('baseline', 'sattler', nan, False)
# ('briggs', 'kmeans', 0.25, False)
# ('briggs', 'sattler', nan, False)
# ('kmeans', 'sattler', nan, False)
# ('meanshift', 'sattler', nan, False)
# Index(['meanshift', 'briggs', 'affinity', 'HDBSCAN', 'kmeans', 'baseline',
#        'sattler'],
#       dtype='object')
# [0, 1, 2, 3, 4, 5, 6]

# %% [markdown]
# ## Section III Part C (Orchestrator Test Set Experiments)

# %% [markdown]
# ### Insertion

# %%
root = os.path.join(EXPERIMENTS_ROOT, EXPERIMENTS[2])
expa_frame = pd.read_csv(os.path.join(root, 'INDE_avg.csv'))
expa_frame.drop(['deletion'], axis=1, inplace=True)
expa_frame.rename(columns={"insertion":"score"}, inplace=True)

for dataset in DATASETS:
    selected_entries = expa_frame[expa_frame['dataset_name'].str.contains(rf'\b{dataset}\b', regex=True)]
    draw_cd_diagram(df_perf=selected_entries, title='Insertion', labels=True, filename=os.path.join(root, dataset, 'cd_plot', 'Insertion_CD_plot.png'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 root = os.path.join(EXPERIMENTS_ROOT, EXPERIMENTS[2])
#       2 expa_frame = pd.read_csv(os.path.join(root, 'INDE_avg.csv'))
#       3 expa_frame.drop(['deletion'], axis=1, inplace=True)
#
# NameError: name 'os' is not defined

# %% [markdown]
# ### Deletion

# %%
root = os.path.join(EXPERIMENTS_ROOT, EXPERIMENTS[2])
expa_frame = pd.read_csv(os.path.join(root, 'INDE_avg.csv'))
expa_frame.drop(['insertion'], axis=1, inplace=True)
expa_frame.rename(columns={"deletion":"score"}, inplace=True)

for dataset in DATASETS:
    selected_entries = expa_frame[expa_frame['dataset_name'].str.contains(rf'\b{dataset}\b', regex=True)]
    draw_cd_diagram(df_perf=selected_entries, title='Deletion', labels=True, filename=os.path.join(root, dataset, 'cd_plot', 'Deletion_CD_plot.png'))
# Out:
# ['baseline' 'briggs' 'sattler' 'kmeans' 'affinity' 'meanshift' 'HDBSCAN']
# the null hypothesis over the entire classifiers cannot be rejected
# HDBSCAN      1.0
# affinity     0.0
# baseline     0.0
# briggs       1.0
# kmeans       0.0
# meanshift    2.0
# sattler      0.0
# dtype: float64
# briggs       5.25
# sattler      4.75
# baseline     4.25
# kmeans       4.25
# affinity     3.75
# HDBSCAN      3.25
# meanshift    2.50
# dtype: float64
# ('HDBSCAN', 'kmeans', 0.125, False)
# ('baseline', 'meanshift', 0.25, False)
# ('briggs', 'meanshift', 0.25, False)
# ('kmeans', 'meanshift', 0.25, False)
# ('meanshift', 'sattler', 0.25, False)
# ('HDBSCAN', 'briggs', 0.375, False)
# ('HDBSCAN', 'sattler', 0.375, False)
# ('affinity', 'meanshift', 0.375, False)
# ('kmeans', 'sattler', 0.375, False)
# ('HDBSCAN', 'affinity', 0.625, False)
# ('HDBSCAN', 'baseline', 0.625, False)
# ('HDBSCAN', 'meanshift', 0.625, False)
# ('affinity', 'baseline', 0.625, False)
# ('affinity', 'briggs', 0.625, False)
# ('affinity', 'kmeans', 0.625, False)
# ('affinity', 'sattler', 0.625, False)
# ('baseline', 'kmeans', 0.625, False)
# ('baseline', 'sattler', 0.625, False)
# ('briggs', 'kmeans', 0.625, False)
# ('baseline', 'briggs', 0.875, False)
# ('briggs', 'sattler', 0.875, False)
# Index(['briggs', 'sattler', 'baseline', 'kmeans', 'affinity', 'HDBSCAN',
#        'meanshift'],
#       dtype='object')
# [0, 1, 2, 3, 4, 5, 6]
# ['baseline' 'briggs' 'sattler' 'kmeans' 'affinity' 'meanshift' 'HDBSCAN']
# HDBSCAN      1.0
# affinity     0.0
# baseline     0.0
# briggs       0.0
# kmeans       0.0
# meanshift    2.0
# sattler      1.0
# dtype: float64
# baseline     6.75
# briggs       6.25
# sattler      4.00
# affinity     3.00
# kmeans       3.00
# HDBSCAN      2.75
# meanshift    2.25
# dtype: float64
# ('HDBSCAN', 'baseline', 0.125, False)
# ('HDBSCAN', 'briggs', 0.125, False)
# ('affinity', 'baseline', 0.125, False)
# ('affinity', 'briggs', 0.125, False)
# ('baseline', 'kmeans', 0.125, False)
# ('baseline', 'meanshift', 0.125, False)
# ('baseline', 'sattler', 0.125, False)
# ('briggs', 'kmeans', 0.125, False)
# ('briggs', 'meanshift', 0.125, False)
# ('briggs', 'sattler', 0.125, False)
# ('affinity', 'sattler', 0.25, False)
# ('baseline', 'briggs', 0.375, False)
# ('kmeans', 'meanshift', 0.375, False)
# ('kmeans', 'sattler', 0.375, False)
# ('meanshift', 'sattler', 0.375, False)
# ('HDBSCAN', 'meanshift', 0.625, False)
# ('HDBSCAN', 'sattler', 0.625, False)
# ('affinity', 'meanshift', 0.625, False)
# ('HDBSCAN', 'affinity', 0.875, False)
# ('HDBSCAN', 'kmeans', 0.875, False)
# ('affinity', 'kmeans', 0.875, False)
# Index(['baseline', 'briggs', 'sattler', 'affinity', 'kmeans', 'HDBSCAN',
#        'meanshift'],
#       dtype='object')
# [0, 1, 2, 3, 4, 5, 6]
# ['baseline' 'briggs' 'sattler' 'kmeans' 'affinity' 'meanshift' 'HDBSCAN']
# HDBSCAN      1.0
# affinity     0.0
# baseline     0.0
# briggs       3.0
# kmeans       0.0
# meanshift    0.0
# sattler      0.0
# dtype: float64
# baseline     6.50
# sattler      6.25
# affinity     4.00
# kmeans       3.75
# meanshift    3.50
# HDBSCAN      2.50
# briggs       1.50
# dtype: float64
# ('HDBSCAN', 'baseline', 0.125, False)
# ('HDBSCAN', 'sattler', 0.125, False)
# ('affinity', 'baseline', 0.125, False)
# ('affinity', 'briggs', 0.125, False)
# ('affinity', 'sattler', 0.125, False)
# ('baseline', 'briggs', 0.125, False)
# ('baseline', 'kmeans', 0.125, False)
# ('baseline', 'meanshift', 0.125, False)
# ('briggs', 'kmeans', 0.125, False)
# ('briggs', 'sattler', 0.125, False)
# ('kmeans', 'sattler', 0.125, False)
# ('HDBSCAN', 'affinity', 0.25, False)
# ('HDBSCAN', 'briggs', 0.25, False)
# ('affinity', 'kmeans', 0.25, False)
# ('briggs', 'meanshift', 0.25, False)
# ('meanshift', 'sattler', 0.25, False)
# ('HDBSCAN', 'kmeans', 0.375, False)
# ('HDBSCAN', 'meanshift', 0.375, False)
# ('affinity', 'meanshift', 0.625, False)
# ('baseline', 'sattler', 0.625, False)
# ('kmeans', 'meanshift', 0.875, False)
# Index(['baseline', 'sattler', 'affinity', 'kmeans', 'meanshift', 'HDBSCAN',
#        'briggs'],
#       dtype='object')
# [0, 1, 2, 3, 4, 5, 6]
# ['baseline' 'briggs' 'sattler' 'kmeans' 'affinity' 'meanshift' 'HDBSCAN']
# the null hypothesis over the entire classifiers cannot be rejected
# HDBSCAN      0.0
# affinity     0.0
# baseline     1.0
# briggs       2.0
# kmeans       1.0
# meanshift    0.0
# sattler      0.0
# dtype: float64
# baseline     5.25
# sattler      5.25
# affinity     4.75
# meanshift    4.75
# briggs       3.00
# HDBSCAN      2.50
# kmeans       2.50
# dtype: float64
# ('HDBSCAN', 'meanshift', 0.125, False)
# ('HDBSCAN', 'sattler', 0.125, False)
# ('affinity', 'briggs', 0.125, False)
# ('kmeans', 'meanshift', 0.125, False)
# ('kmeans', 'sattler', 0.125, False)
# ('HDBSCAN', 'affinity', 0.25, False)
# ('HDBSCAN', 'baseline', 0.25, False)
# ('affinity', 'baseline', 0.25, False)
# ('baseline', 'briggs', 0.25, False)
# ('baseline', 'kmeans', 0.25, False)
# ('baseline', 'meanshift', 0.25, False)
# ('briggs', 'meanshift', 0.25, False)
# ('affinity', 'kmeans', 0.375, False)
# ('baseline', 'sattler', 0.625, False)
# ('briggs', 'sattler', 0.625, False)
# ('HDBSCAN', 'kmeans', 0.875, False)
# ('meanshift', 'sattler', 0.875, False)
# ('HDBSCAN', 'briggs', 1.0, False)
# ('affinity', 'meanshift', 1.0, False)
# ('affinity', 'sattler', 1.0, False)
# ('briggs', 'kmeans', 1.0, False)
# Index(['baseline', 'sattler', 'affinity', 'meanshift', 'briggs', 'HDBSCAN',
#        'kmeans'],
#       dtype='object')
# [0, 1, 2, 3, 4, 5, 6]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # Section III: Exploring Mean Values of Insertion and Deletion for particular methods

# %% [markdown]
# ## Section III Part A (In-Distribution Experiments)

# %%
root = os.path.join(EXPERIMENTS_ROOT, EXPERIMENTS[0])
expa_frame = pd.read_csv(os.path.join(root, 'INDE_avg.csv'))
avg_scores = expa_frame.groupby('algorithm')[['insertion', 'deletion']].mean().reset_index()
# Out:
#    algorithm  insertion  deletion
# 0    HDBSCAN   0.629220  0.452789
# 1   affinity   0.503603  0.409883
# 2   baseline   0.439474  0.289718
# 3     briggs   0.560220  0.386838
# 4     kmeans   0.617185  0.451214
# 5  meanshift   0.597171  0.436794
# 6    sattler   0.467089  0.346826

# %%
avg_scores.sort_values(by='insertion', ascending=False)
# Out:
#    algorithm  insertion  deletion
# 0    HDBSCAN   0.629220  0.452789
# 4     kmeans   0.617185  0.451214
# 5  meanshift   0.597171  0.436794
# 3     briggs   0.560220  0.386838
# 1   affinity   0.503603  0.409883
# 6    sattler   0.467089  0.346826
# 2   baseline   0.439474  0.289718

# %%
avg_scores.sort_values(by='deletion', ascending=False)
# Out:
#    algorithm  insertion  deletion
# 0    HDBSCAN   0.629220  0.452789
# 4     kmeans   0.617185  0.451214
# 5  meanshift   0.597171  0.436794
# 1   affinity   0.503603  0.409883
# 3     briggs   0.560220  0.386838
# 6    sattler   0.467089  0.346826
# 2   baseline   0.439474  0.289718

# %% [markdown]
# ## Section III Part B (Out-of-Distribution Experiments)

# %%
root = os.path.join(EXPERIMENTS_ROOT, EXPERIMENTS[1])
expb_frame = pd.read_csv(os.path.join(root, 'INDE_avg.csv'))
avg_scores = expb_frame.groupby('algorithm')[['insertion', 'deletion']].mean().reset_index()

# %%
avg_scores.sort_values(by='insertion', ascending=False)
# Out:
#    algorithm  insertion  deletion
# 0    HDBSCAN   0.536319  0.380883
# 4     kmeans   0.528579  0.366457
# 1   affinity   0.512877  0.429768
# 5  meanshift   0.505511  0.351870
# 3     briggs   0.338928  0.254167
# 2   baseline        NaN       NaN
# 6    sattler        NaN       NaN

# %%
avg_scores.sort_values(by='deletion', ascending=False)
# Out:
#    algorithm  insertion  deletion
# 1   affinity   0.512877  0.429768
# 0    HDBSCAN   0.536319  0.380883
# 4     kmeans   0.528579  0.366457
# 5  meanshift   0.505511  0.351870
# 3     briggs   0.338928  0.254167
# 2   baseline        NaN       NaN
# 6    sattler        NaN       NaN
